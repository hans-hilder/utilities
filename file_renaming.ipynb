# %%
import os

def rename_file_batch(folder_path,change_from,change_to):

    # Set the directory containing your .lnk files
    # folder_path = r"C:\Users\hanshil\OneDrive - NOC\Documents\Ocean_Optics\SINK_Data\SINK2025\LISST\20250601_reprocess"

    for filename in os.listdir(folder_path):
        if change_from in filename:
            original_path = os.path.join(folder_path, filename)
            new_filename = filename.replace(change_from, change_to)
            new_path = os.path.join(folder_path, new_filename)

            os.rename(original_path, new_path)
            print(f"Renamed: {filename} -> {new_filename}")

# %%
folder_path = "C:\\Users\\hanshil\\Documents\\MATLAB\\OceanOptics\\data\\SINK_Data\\SINK2025\\LISST\\20250601_reprocess"

rename_file_batch(folder_path,"_2_","_")
# Out:
# Renamed: dre_1015_2_pre_ejs_hah_06012025.asc -> dre_1015_pre_ejs_hah_06012025.asc
# Renamed: dre_1015_2_pre_ejs_hah_06012025.log -> dre_1015_pre_ejs_hah_06012025.log
# Renamed: dre_1015_2_pre_ejs_hah_06012025.psd -> dre_1015_pre_ejs_hah_06012025.psd
# Renamed: dre_1015_2_pre_ejs_hah_06012025_rs.asc -> dre_1015_pre_ejs_hah_06012025_rs.asc
# Renamed: dre_1015_2_pre_ejs_hah_06012025_rs.psd -> dre_1015_pre_ejs_hah_06012025_rs.psd
